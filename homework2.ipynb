# %% [markdown]
# # HOMEWORK 2

# %% [markdown]
# Bài 1 : Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a, b = map(float, input(). split())
p = (a+b)*2
s = a*b
print(f"Chu vi hinh chu nhat la {p}")
print(f"Dien tich hinh chu nhat la {s}")
# Out:
# Chu vi hinh chu nhat la 6.0
# Dien tich hinh chu nhat la 2.0

# %% [markdown]
# Bài 2 : Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r = float(input())
p  = 2*3.14*r
s = 3.14*(r**2)
print(f"Chu vi hinh tron la {p}")
print(f"Dien tich hinh tron la {s}")
# Out:
# Chu vi hinh tron la 6.28
# Dien tich hinh tron la 3.14

# %% [markdown]
# Bài 3 :  Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
import math 
a, b, c = map(float, input(). split())
if (a+b)<c or (a+c)<b or (b+c)<a:
    print("Khong la ba canh cua mot tam giac")
elif a == b == c:
    print("Day la tam giac deu")
elif a == b != c or a == c != b or b == c != a:
    print("Day la tam giac can")
else : 
    print("Day la tam giac thuong")
p = (a+b+c)/2
s = math.sqrt(p*(p-a)*(p-b)*(p-c))
print(f"Chu vi tam giac la {p}")
print(f"Dien tich tam giac la {s}")
# Out:
# Day la tam giac can
# Chu vi tam giac la 3.5
# Dien tich tam giac la 1.984313483298443

# %% [markdown]
# Bài 4 : Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float, input(). split())
if a== 0 : 
    if b == 0: 
        print("Vo so nghiem")
    else: 
        print("Vo nghiem")
else: 
    x = -b/a 
    print(x)
# Out:
# Vo nghiem

# %% [markdown]
# Bài 5 : Viết chương trình giải phương trình bậc 2 (ax^2 + bx + c = 0)

# %%
import math
a, b, c = map(float, input(). split())
if a == 0: 
    if b==0: 
        if c==0:
            print("Vo so nghiem")
        else:
            print("Vo nghiem")
    else: 
        x=-c/b
        print(f"Phuong trinh co 1 nghiem x = {x}")
else: 
    delta = b**2 - 4*a*c 
    if delta < 0: 
        print("Vo nghiem")
    elif delta == 0:
        x = -b / 2*a 
        print(f"Phuong trinh co 1 nghiem kep x = {x}")
    else:
        x1 = (-b - math.sqrt(delta))/2*a
        x2 = (-b - math.sqrt(delta))/2*a
        print(f"Phuong trinh co 2 nghiem x1 = {x1} va x2 = {x2}")
# Out:
# Phuong trinh co 2 nghiem x1 = -4.302775637731995 va x2 = -4.302775637731995

# %% [markdown]
# Bài 6 : Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, d được nhập từ bàn phím).

# %%
a, b, c, d = map(float, input(). split())
print(max(a, b, c, d))
# Out:
# 7.2

# %% [markdown]
# Bài 7 : Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, d được nhập từ bàn phím).

# %%
a, b, c, d = map(float, input(). split())
print(min(a, b, c, d))
# Out:
# 1.2

# %% [markdown]
# Bài 8 : Giải hệ phương trình tuyến tính: ax + by = m , cx + dy = n

# %%
a, b, m, c, d, n = map(float, input().split())
y = (a*n - c*m) / (a*d - b*c) 
x = (m - b*y) / a             
print(x, y)
# Out:
# -1.0 2.0

# %% [markdown]
# Bài 9 : Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
s = int(input())
gio = s//3600 
phut = (s - gio*3600)//60 
giay = s - gio*3600 - phut*60
print(f"{gio} gio {phut} phut {giay} giay")
# Out:
# 1 gio 1 phut 6 giay

# %% [markdown]
# Bài 10 : Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
import math 
print("Nhap thong tin duong tron")
x_c = float(input())
y_c = float(input())
r = float(input())
print("Nhap toa do diem A")
x_a = float(input())
y_a = float(input())
d = math.sqrt((x_a - x_c)**2 + (y_a - y_c)**2)
if d <= r: 
    print("A thuoc duong tron")
else: 
    print("A khong thuoc duong tron")
# Out:
# Nhap thong tin duong tron
# Nhap toa do diem A
# A thuoc duong tron

# %% [markdown]
# Bài 11 : Tính x^y (Với x, y là số thực).

# %%
x, y = map(float, input(). split())
ket_qua = x**y
print(ket_qua)
# Out:
# 0.5
